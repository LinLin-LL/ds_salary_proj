# %%
import pandas as pd

# %%
data = pd.read_csv('glassdoor_jobs.csv')
data
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                     Project Manager/Senior Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995         Senior Data Scientist, Product Development
# 996              Senior Scientist, Analytical Sciences
# 997  Sr. Research Associate/ Scientist, NGS prep & ...
# 998                   Data Analyst - Unilever Prestige
# 999                         IT Data Engineer Associate
#
#                   Salary Estimate  \
# 0     $70K-$116K (Glassdoor est.)
# 1     $83K-$135K (Glassdoor est.)
# 2                              -1
# 3                              -1
# 4     $75K-$131K (Glassdoor est.)
# ..                            ...
# 995    $104K-$140K(Employer est.)
# ...

# %% [markdown]
# ## salary parsing

# %%
df = data.copy()
df['hourly'] = df['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df['employer_provided'] = df['Salary Estimate'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                                       Data Scientist
# 2                                       Data Scientist
# 3                     Project Manager/Senior Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 995         Senior Data Scientist, Product Development
# 996              Senior Scientist, Analytical Sciences
# 997  Sr. Research Associate/ Scientist, NGS prep & ...
# 998                   Data Analyst - Unilever Prestige
# 999                         IT Data Engineer Associate
#
#                   Salary Estimate  \
# 0     $70K-$116K (Glassdoor est.)
# 1     $83K-$135K (Glassdoor est.)
# 2                              -1
# 3                              -1
# 4     $75K-$131K (Glassdoor est.)
# ..                            ...
# 995    $104K-$140K(Employer est.)
# ...

# %%
df = df[df['Salary Estimate'] != '-1']
df.shape
# Out:
# (616, 16)

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split('(')[0])
salary
# Out:
# 0       $70K-$116K
# 1       $83K-$135K
# 4       $75K-$131K
# 5       $96K-$101K
# 6        $31K-$67K
#            ...
# 994      $61K-$74K
# 995     $104K-$140K
# 996    $110K-$201K
# 998      $51K-$55K
# 999     $98K-$180K
# Name: Salary Estimate, Length: 616, dtype: object

# %%
minus_Kd = salary.apply(lambda x: x.replace('K', '').replace('$', ''))
minus_Kd
# Out:
# 0       70-116
# 1       83-135
# 4       75-131
# 5       96-101
# 6        31-67
#          ...
# 994      61-74
# 995     104-140
# 996    110-201
# 998      51-55
# 999     98-180
# Name: Salary Estimate, Length: 616, dtype: object

# %%
min_hr = minus_Kd.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary: ',''))
min_hr
# Out:
# 0       70-116
# 1       83-135
# 4       75-131
# 5       96-101
# 6        31-67
#          ...
# 994      61-74
# 995     104-140
# 996    110-201
# 998      51-55
# 999     98-180
# Name: Salary Estimate, Length: 616, dtype: object

# %%
df = df.copy()
df['min_salary'] = min_hr.apply(lambda x: int(x.split('-')[0]))
df['max_salary'] = min_hr.apply(lambda x: int(x.split('-')[1]))
df['avg_salary'] = (df.min_salary+df.max_salary)/2
df
# Out:
#                                       Job Title               Salary Estimate  \
# 0                                Data Scientist   $70K-$116K (Glassdoor est.)
# 1                                Data Scientist   $83K-$135K (Glassdoor est.)
# 4                                Data Scientist   $75K-$131K (Glassdoor est.)
# 5      Data Scientist / Machine Learning Expert   $96K-$101K (Glassdoor est.)
# 6                Market Research Data Scientist    $31K-$67K (Glassdoor est.)
# ..                                          ...                           ...
# 994                           Big Data Engineer    $61K-$74K (Glassdoor est.)
# 995  Senior Data Scientist, Product Development    $104K-$140K(Employer est.)
# 996       Senior Scientist, Analytical Sciences  $110K-$201K (Glassdoor est.)
# 998            Data Analyst - Unilever Prestige    $51K-$55K (Glassdoor est.)
# 999                  IT Data Engineer Associate   $98K-$180K (Glassdoor est.)
#
# ...

# %% [markdown]
# ## company name text only

# %%
df = df.copy()
df['company_txt'] = df.apply(lambda x: x['Company Name'] if x['Rating'] < 0 else x['Company Name'][:-3], axis = 1)
df
# Out:
#                                       Job Title               Salary Estimate  \
# 0                                Data Scientist   $70K-$116K (Glassdoor est.)
# 1                                Data Scientist   $83K-$135K (Glassdoor est.)
# 4                                Data Scientist   $75K-$131K (Glassdoor est.)
# 5      Data Scientist / Machine Learning Expert   $96K-$101K (Glassdoor est.)
# 6                Market Research Data Scientist    $31K-$67K (Glassdoor est.)
# ..                                          ...                           ...
# 994                           Big Data Engineer    $61K-$74K (Glassdoor est.)
# 995  Senior Data Scientist, Product Development    $104K-$140K(Employer est.)
# 996       Senior Scientist, Analytical Sciences  $110K-$201K (Glassdoor est.)
# 998            Data Analyst - Unilever Prestige    $51K-$55K (Glassdoor est.)
# 999                  IT Data Engineer Associate   $98K-$180K (Glassdoor est.)
#
# ...

# %% [markdown]
# ## state field

# %%
df = df.copy()
df['job_state'] = df['Location'].apply(lambda x: x.split(",")[1] if len(x.split(",")) == 2 else x.split(",")[len(x.split(","))-1])
df
# Out:
#                                       Job Title               Salary Estimate  \
# 0                                Data Scientist   $70K-$116K (Glassdoor est.)
# 1                                Data Scientist   $83K-$135K (Glassdoor est.)
# 4                                Data Scientist   $75K-$131K (Glassdoor est.)
# 5      Data Scientist / Machine Learning Expert   $96K-$101K (Glassdoor est.)
# 6                Market Research Data Scientist    $31K-$67K (Glassdoor est.)
# ..                                          ...                           ...
# 994                           Big Data Engineer    $61K-$74K (Glassdoor est.)
# 995  Senior Data Scientist, Product Development    $104K-$140K(Employer est.)
# 996       Senior Scientist, Analytical Sciences  $110K-$201K (Glassdoor est.)
# 998            Data Analyst - Unilever Prestige    $51K-$55K (Glassdoor est.)
# 999                  IT Data Engineer Associate   $98K-$180K (Glassdoor est.)
#
# ...

# %%
df.job_state.value_counts()
# Out:
#  CA    131
#  VA     90
#  MA     84
#  NY     52
#  WA     35
#  MD     29
#  IL     24
#  DC     24
#  NC     16
#  WI     15
#  OH     13
#  MO     11
#  PA     10
#  CO     10
#  TX      9
#  OR      8
#  FL      5
#  MN      5
#  NE      5
#  OK      5
#  NJ      4
#  SC      3
#  UT      3
#  MI      3
#  RI      3
#  GA      3
#  AZ      3
#  TN      2
#  IN      2
#  IA      2
#  CT      1
#  WV      1
#  KS      1
#  HI      1
#  AL      1
#  LA      1
#  MS      1
# Name: job_state, dtype: int64

# %%
df['same_state'] = df.apply(lambda x: 1 if x.Location == x.Headquarters else 0, axis = 1)
df
# Out:
#                                       Job Title               Salary Estimate  \
# 0                                Data Scientist   $70K-$116K (Glassdoor est.)
# 1                                Data Scientist   $83K-$135K (Glassdoor est.)
# 4                                Data Scientist   $75K-$131K (Glassdoor est.)
# 5      Data Scientist / Machine Learning Expert   $96K-$101K (Glassdoor est.)
# 6                Market Research Data Scientist    $31K-$67K (Glassdoor est.)
# ..                                          ...                           ...
# 994                           Big Data Engineer    $61K-$74K (Glassdoor est.)
# 995  Senior Data Scientist, Product Development    $104K-$140K(Employer est.)
# 996       Senior Scientist, Analytical Sciences  $110K-$201K (Glassdoor est.)
# 998            Data Analyst - Unilever Prestige    $51K-$55K (Glassdoor est.)
# 999                  IT Data Engineer Associate   $98K-$180K (Glassdoor est.)
#
# ...

# %% [markdown]
# ## age of company

# %%
df['age'] = df.Founded.apply(lambda x: x if x<1 else 2020 - x)
df
# Out:
#                                       Job Title               Salary Estimate  \
# 0                                Data Scientist   $70K-$116K (Glassdoor est.)
# 1                                Data Scientist   $83K-$135K (Glassdoor est.)
# 4                                Data Scientist   $75K-$131K (Glassdoor est.)
# 5      Data Scientist / Machine Learning Expert   $96K-$101K (Glassdoor est.)
# 6                Market Research Data Scientist    $31K-$67K (Glassdoor est.)
# ..                                          ...                           ...
# 994                           Big Data Engineer    $61K-$74K (Glassdoor est.)
# 995  Senior Data Scientist, Product Development    $104K-$140K(Employer est.)
# 996       Senior Scientist, Analytical Sciences  $110K-$201K (Glassdoor est.)
# 998            Data Analyst - Unilever Prestige    $51K-$55K (Glassdoor est.)
# 999                  IT Data Engineer Associate   $98K-$180K (Glassdoor est.)
#
# ...

# %% [markdown]
# ## parsing of job description (python, etc.)

# %%
df['python'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df.python.value_counts()
# Out:
# 1    389
# 0    227
# Name: python, dtype: int64

# %%
df['r'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() or 'rstudio' in x.lower() or 'r-studio' in x.lower() else 0)
df.r.value_counts()
# Out:
# 0    610
# 1      6
# Name: r, dtype: int64

# %%
df['spark'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df.spark.value_counts()
# Out:
# 0    429
# 1    187
# Name: spark, dtype: int64

# %%
df['aws'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df.aws.value_counts()
# Out:
# 0    487
# 1    129
# Name: aws, dtype: int64

# %%
df['excel'] = df['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
df.excel.value_counts()
# Out:
# 0    341
# 1    275
# Name: excel, dtype: int64

# %%
df.to_csv('salary_data_clean.csv', index=False)
