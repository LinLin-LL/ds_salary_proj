# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_clean.csv')
df.head()
# Out:
#                                   Job Title              Salary Estimate  \
# 0                            Data Scientist  $70K-$116K (Glassdoor est.)
# 1                            Data Scientist  $83K-$135K (Glassdoor est.)
# 2                            Data Scientist  $75K-$131K (Glassdoor est.)
# 3  Data Scientist / Machine Learning Expert  $96K-$101K (Glassdoor est.)
# 4            Market Research Data Scientist   $31K-$67K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Secure our Nation, Ignite your Future\r\n\r\nJ...     4.2
# 1  Data Scientist, Risk (4+ years of experience)\...     4.6
# 2  Overview\r\n\r\n\r\nAnalysis Group is one of t...     3.8
# 3  Posting Title\r\nData Scientist / Machine Lear...     3.9
# 4  About Us\r\n\r\nAt GutCheck, we pioneered agil...     3.8
#
#             Company Name           Location        Headquarters  \
# 0         ManTech\r\n4.2      Chantilly, VA         Herndon, VA
# 1            Turo\r\n4.6  San Francisco, CA   San Francisco, CA
# 2  Analysis Group\r\n3.8         Boston, MA          Boston, MA
# 3        Novartis\r\n3.9      Cambridge, MA  Basel, Switzerland
# 4        GutCheck\r\n3.8         Denver, CO          Denver, CO
#
#                       Size  Founded        Type of ownership  ... avg_salary  \
# 0  5001 to 10000 employees     1968         Company - Public  ...       93.0
# 1     201 to 500 employees     2009        Company - Private  ...      109.0
# 2   1001 to 5000 employees     1981  Private Practice / Firm  ...      103.0
# 3         10000+ employees     1996         Company - Public  ...       98.5
# 4      51 to 200 employees     2009        Company - Private  ...       49.0
#
#           company_txt job_state same_state  age  python  r  spark  aws excel
# 0         ManTech\r\n        VA          0   52       0  0      0    0     0
# 1            Turo\r\n        CA          1   11       1  0      0    1     0
# 2  Analysis Group\r\n        MA          1   39       1  0      0    1     1
# 3        Novartis\r\n        MA          0   24       1  0      0    0     0
# 4        GutCheck\r\n        CO          1   11       0  0      0    0     1
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python', 'r', 'spark',
#        'aws', 'excel'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer'in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'jr'
    else:
        return 'na'

## job title and seniority

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)
df.job_simp.value_counts()
# Out:
# data scientist    333
# analyst            79
# data engineer      79
# na                 69
# mle                41
# manager            12
# director            3
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        444
# senior    170
# jr          2
# Name: seniority, dtype: int64

# %% [markdown]
# ## job description length

# %%
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      4110
# 1      4294
# 2      8844
# 3      5126
# 4      3098
#        ...
# 611    3082
# 612    4584
# 613    3338
# 614    2876
# 615    6952
# Name: desc_len, Length: 616, dtype: int64

# %% [markdown]
# ## competitor count

# %%
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['num_comp']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      3
#       ..
# 611    0
# 612    0
# 613    0
# 614    3
# 615    0
# Name: num_comp, Length: 616, dtype: int64

# %% [markdown]
# ## hourly wage to annual

# %%
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis = 1) 
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis = 1) 
df[df.hourly == 1][['hourly', 'min_salary', 'max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 186       1          34          46
# 286       1          34          46
# 373       1          34          46

# %% [markdown]
# ## remove new line from job title

# %%
df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\r\n', ''))
#df['company_txt'] = df.company_txt.apply(lambda x: x.replace('\r', ''))

df['company_txt']
# Out:
# 0                              ManTech
# 1                                 Turo
# 2                       Analysis Group
# 3                             Novartis
# 4                             GutCheck
#                     ...
# 611                        CaptiveAire
# 612           Adaptive Biotechnologies
# 613                 FORMA THERAPEUTICS
# 614                        Dermalogica
# 615    Global Atlantic Financial Group
# Name: company_txt, Length: 616, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  616.000000   616.000000  616.000000              616.0  616.000000
# mean     3.808117  1885.987013    0.004870                0.0   86.357143
# std      0.564937   421.858239    0.069673                0.0   29.369123
# min     -1.000000    -1.000000    0.000000                0.0   14.000000
# 25%      3.500000  1959.250000    0.000000                0.0   66.750000
# 50%      3.800000  1996.000000    0.000000                0.0   83.000000
# 75%      4.100000  2008.000000    0.000000                0.0  104.000000
# max      5.000000  2019.000000    1.000000                0.0  212.000000
#
#        max_salary  avg_salary  same_state         age      python           r  \
# count  616.000000  616.000000  616.000000  616.000000  616.000000  616.000000
# mean   130.823052  108.492695    0.524351   38.821429    0.631494    0.009740
# std     39.921869   33.565631    0.499813   42.940578    0.482792    0.098291
# min     44.000000   20.000000    0.000000   -1.000000    0.000000    0.000000
# 25%    102.000000   87.000000    0.000000   10.750000    0.000000    0.000000
# 50%    128.000000  107.000000    1.000000   23.000000    1.000000    0.000000
# 75%    152.000000  125.500000    1.000000   51.250000    1.000000    0.000000
# max    331.000000  271.500000    1.000000  239.000000    1.000000    1.000000
#
#             spark         aws       excel      desc_len    num_comp
# count  616.000000  616.000000  616.000000    616.000000  616.000000
# mean     0.303571    0.209416    0.446429   3982.357143    1.051948
# std      0.460173    0.407222    0.497526   1771.673471    1.388886
# min      0.000000    0.000000    0.000000     73.000000    0.000000
# 25%      0.000000    0.000000    0.000000   2895.000000    0.000000
# 50%      0.000000    0.000000    0.000000   3720.000000    0.000000
# 75%      1.000000    0.000000    1.000000   4839.250000    3.000000
# max      1.000000    1.000000    1.000000  10681.000000    3.000000

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot('avg_salary')

# %%
df[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000   -0.112367 -0.107447  0.179158
# avg_salary -0.112367    1.000000  0.102096  0.157818
# Rating     -0.107447    0.102096  1.000000  0.063067
# desc_len    0.179158    0.157818  0.063067  1.000000

# %%
# https://seaborn.pydata.org/examples/many_pairwise_correlations.html

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(df[['age', 'avg_salary', 'Rating', 'desc_len']].corr(), cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python', 'r', 'spark',
#        'aws', 'excel', 'job_simp', 'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state', 'same_state', 'python', 'r', 'spark', 'aws', 'excel', 'job_simp', 'seniority']]

# %%
# https://seaborn.pydata.org/generated/seaborn.barplot.html
# https://www.drawingfromdata.com/how-to-rotate-axis-labels-in-seaborn-and-matplotlib
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 20
# graph for Headquarters: total = 20
# graph for Size: total = 8
# graph for Type of ownership: total = 9
# graph for Industry: total = 20
# graph for Sector: total = 19
# graph for Revenue: total = 13
# graph for company_txt: total = 20
# graph for job_state: total = 20
# graph for same_state: total = 2
# graph for python: total = 2
# graph for r: total = 2
# graph for spark: total = 2
# graph for aws: total = 2
# graph for excel: total = 2
# graph for job_simp: total = 7
# graph for seniority: total = 3

# %%
pd.pivot_table(df, index='job_simp', values='avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          72.930380
# data engineer   108.000000
# data scientist  115.588589
# director        132.500000
# manager         102.458333
# mle             121.695122
# na              107.688406

# %%
pd.pivot_table(df, index=['job_simp', 'seniority'], values='avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          56.500000
#                na          64.454545
#                senior      95.613636
# data engineer  na         101.018519
#                senior     123.080000
# data scientist na         106.502024
#                senior     141.686047
# director       na         179.500000
#                senior     109.000000
# manager        na          94.875000
#                senior     117.625000
# mle            na         114.741935
#                senior     143.250000
# na             na          99.906250
#                senior     125.476190

# %%
pd.pivot_table(df, index='job_state', values='avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
#  CA        133.160305
#  NY        127.096154
#  MA        119.690476
#  RI        114.166667
#  MD        113.500000
#  UT        106.833333
#  MI        104.000000
#  IL        102.104167
#  CO        100.550000
#  DC         99.645833
#  OR         99.250000
#  GA         99.166667
#  NJ         97.875000
#  WA         96.800000
#  VA         96.233333
#  KS         96.000000
#  OH         90.230769
#  AZ         90.000000
#  MO         88.772727
#  MN         87.900000
#  NC         87.531250
#  CT         86.500000
#  FL         82.800000
#  PA         81.000000
#  AL         81.000000
#  TX         80.500000
#  HI         80.000000
#  NE         75.200000
#  WI         75.200000
#  TN         71.500000
#  LA         67.000000
#  OK         66.700000
#  WV         63.500000
#  MS         57.000000
#  SC         55.000000
#  IN         54.000000
#  IA         43.000000

# %%
pd.pivot_table(df, index='Sector', columns='python', values='avg_salary', aggfunc='count')
# Out:
# python                           0      1
# Sector
# -1                             8.0    3.0
# Aerospace & Defense           10.0   41.0
# Agriculture & Forestry         1.0    NaN
# Biotech & Pharmaceuticals     44.0   64.0
# Business Services             27.0   48.0
# Consumer Services              NaN    4.0
# Education                      2.0    3.0
# Finance                       27.0   17.0
# Government                     NaN    9.0
# Health Care                    9.0    4.0
# Information Technology        48.0  122.0
# Insurance                     19.0   35.0
# Manufacturing                  8.0   25.0
# Media                          1.0    2.0
# Oil, Gas, Energy & Utilities  17.0    NaN
# Retail                         2.0    6.0
# Telecommunications             1.0    2.0
# Transportation & Logistics     2.0    2.0
# Travel & Tourism               1.0    2.0

# %% [markdown]
# ## word cloud

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
